# %% [markdown]
# ## Working with Text Files

# %% [markdown]
# Text files are probably the most basic types of files that you are <br> going to encounter in your NLP endeavors. In this section, we <br> will see how to read from a text file in Python, create a text file, and write data to the text file.

# %% [markdown]
# ### Reading a Text File

# %%
myfile = open("text_file.txt")

# %%
myfile
# Out:
# <_io.TextIOWrapper name='text_file.txt' mode='r' encoding='UTF-8'>

# %%
myfile.read()
# Out:
# 'Welcome to Natural Language Processing\nIt is one of the most exciting research areas as of today\nWe will see how Python can be used to work with text files.\n'

# %% [markdown]
# Now if you try to call the read method again, you will see that nothing will be printed on the console:

# %%
myfile.read()
# Out:
# ''

# %% [markdown]
# This is because once you call the read method, the cursor is moved to the end of the text. Therefore, when you call read again, nothing is displayed since there is no more text to print.

# %% [markdown]
# A solution to this problem is that after calling the read() method, call the seek() method and pass 0 as the argument. This will move the cursor back to the start of the text file. Look at the following script to see how this works:

# %%
myfile = open("text_file.txt")
print(myfile.read())
myfile.seek(0)
print(myfile.read())
# Out:
# Welcome to Natural Language Processing
# It is one of the most exciting research areas as of today
# We will see how Python can be used to work with text files.
#
# Welcome to Natural Language Processing
# It is one of the most exciting research areas as of today
# We will see how Python can be used to work with text files.

# %%
myfile.close()

# %% [markdown]
# **Reading a File Line by Line**

# %% [markdown]
# Instead of reading all the contents of the file at once, we can also read the file contents line by line.<br> To do so, we need to execute the readlines() method, which returns each line in the text file as list item.

# %%
myfile = open("text_file.txt")
print(myfile.readlines())
# Out:
# ['Welcome to Natural Language Processing\n', 'It is one of the most exciting research areas as of today\n', 'We will see how Python can be used to work with text files.\n']

# %% [markdown]
# In many cases this makes the text easier to work with.<br> For example, we can now easily iterate through each line and print the first word in the line.

# %%
myfile = open("text_file.txt")
for lines in myfile:
    print(lines.split()[0])
# Out:
# Welcome
# It
# We

# %% [markdown]
# ### Writing to a Text File

# %% [markdown]
# To write to a text file, you simply have to open a file with mode set to w or w+. The former opens a file in the write mode, while the latter opens the file in both read and write mode. If the file doesn't exist, it will be created. It is important to mention that if you open a file that already contains some text with w or w+ mode, all the existing file contents will be removed, as shown below:

# %%
myfile = open("text_file.txt", 'w+')
print(myfile.read())

# %%
myfile = open("text_file.txt", 'w+')
print(myfile.read())
myfile.write("The file has been rewritten")
myfile.seek(0)
print(myfile.read())
# Out:
# The file has been rewritten

# %% [markdown]
# Often times, you dont simply need to wipe out the existing contents of the file. Rather, you may need to add the contents at the end of the file.

# %% [markdown]
# To do so, you need to open the file with a+ mode which refers to append plus read.

# %%
myfile = open("text_file.txt", 'a+')
myfile.seek(0)
print(myfile.read())
# Out:
# Welcome to Natural Language Processing
# It is one of the most exciting research areas as of today
# We will see how Python can be used to work with text files.

# %%
myfile.write("\nThis is a new line")
# Out:
# 19

# %%
myfile.seek(0)
print(myfile.read())
# Out:
# Welcome to Natural Language Processing
# It is one of the most exciting research areas as of today
# We will see how Python can be used to work with text files.
#
# This is a new line

# %% [markdown]
# Using the with keyword, as shown below, you don't <br> need to explicitly close the file. Rather, the <br>  above script opens the file, reads its <br> contents, and then closes it automatically.

# %%
with open("text_file.txt") as myfile:
    print(myfile.read())
# Out:
# Welcome to Natural Language Processing
# It is one of the most exciting research areas as of today
# We will see how Python can be used to work with text files.
#
# This is a new line

# %% [markdown]
# ### Working with PDF Files

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz (77kB)
#      |████████████████████████████████| 81kB 2.1MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61086 sha256=2ffe138f7b34da3824e5025945a95c4b84145f6cbe92a341779c87d45366862f
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
import PyPDF2
mypdf = open('Lorem-Ipsum.pdf', mode='rb')

# %%
pdf_document = PyPDF2.PdfFileReader(mypdf)

# %%
pdf_document.numPages
# Out:
# 1

# %%
first_page = pdf_document.getPage(0)

print(first_page.extractText())
# Out:
# Lorem Ipsum
# is simply dummy text of the printing and typesetting
# industry. Lorem Ipsum has been the industry's standard dummy text ever
# since the 1500s, when an unknown printer took a galley of type and
# scrambled it to make a type specimen book. It has survived not only five
# centuries, but also the leap into electronic typesetting, remaining essentially
# unchanged. It was popularised in the 1960s with the release of Letraset
# sheets containing Lorem Ipsum passages, and more recently with desktop
# publishing software like Aldus PageMaker including versions of Lorem Ipsum.It is a long established fact that a reader will be distracted by the readable
# content of a page when looking at its layout. The point of using Lorem Ipsum is that it has a more-or-less normal distribution of letters, as opposed to
# using 'Content here, content here', making it look like readable English.
# Many desktop publishing packages and web page editors now use Lorem
# Ipsum as their default model text, and a search for 'lorem ipsum' will
# uncover many web sites still in their infancy. Various versions have evolved
# over the years, sometimes by accident, sometimes on purpose (injected
# humour and the like).Contrary to popular belief, Lorem Ipsum is not simply random text. It has
# roots in a pieceof classical Latin literature from 45 BC, making it over 2000
# years old. Richard McClintock, a Latin professor at Hampden-Sydney College
# in Virginia, looked up one of the more obscure Latin words, consectetur,
# from a Lorem Ipsum passage, and going throughthe cites of the word in
# classical literature, discovered the undoubtable source. Lorem Ipsum comes
# from sections 1.10.32 and 1.10.33 of "de Finibus Bonorum et Malorum" (The
# Extremes of Good and Evil) by Cicero, written in 45 BC. This book is a
# treatise on the theory of ethics, very popular during the Renaissance. The
# first line of Lorem Ipsum, "Lorem ipsum dolor sit amet..", comes from a line
# in section 1.10.32.The standard chunk of Lorem Ipsum used since the 1500s is reproduced
# below for those interested. Sections 1.10.32 and 1.10.33 from "de Finibus
# Bonorum et Malorum" by Cicero are also reproduced in their exact original
# form, accompanied by English versions from the 1914 translation by H.
# Rackham.

# %% [markdown]
# ### Writing to a PDF Document

# %% [markdown]
# It is not possible to directly write Python strings to PDF document using the PyPDF2 library due to fonts and other constraints. However, for the sake of demonstration, we will read contents from our PDF document and then will write that content to another PDF file that we will create.

# %%
import PyPDF2

mypdf = open('Lorem-Ipsum.pdf', mode='rb')
pdf_document = PyPDF2.PdfFileReader(mypdf)
pdf_document.numPages

page_one = pdf_document.getPage(0)

# %%
pdf_document_writer = PyPDF2.PdfFileWriter()

# %%
pdf_document_writer.addPage(page_one)

# %%
pdf_output_file = open('new_pdf_file.pdf', 'wb')

# %%
pdf_document_writer.write(pdf_output_file)

# %%
import PyPDF2

mypdf = open(r'new_pdf_file.pdf', mode='rb')

pdf_document = PyPDF2.PdfFileReader(mypdf)
pdf_document.numPages
page_one = pdf_document.getPage(0)

print(page_one.extractText())

# %% [markdown]
# ### Let's now work with a bigger PDF file

# %%
import PyPDF2

mypdf = open(r'lipsum.pdf', mode='rb')
pdf_document = PyPDF2.PdfFileReader(mypdf)
pdf_document.numPages
# Out:
# 87

# %%
import PyPDF2

mypdf = open(r'lipsum.pdf', mode='rb')
pdf_document = PyPDF2.PdfFileReader(mypdf)

for i in range(pdf_document.numPages):
    page_to_print = pdf_document.getPage(i)
    print(page_to_print.extractText())
# Out:
# Streaming output truncated to the last 5000 lines.
# vestibulumrisus,vitaemattismetusnequenonpede.}
# 1988
# %{123}
# 1989
# \NewLipsumPar{Suspendissemolliseratetrisus.Vestibulum
# 1990
# etodioeunislmalesuadadapibus.Morbiactortoretmagna
# 1991
# tinciduntullamcorper.Utpellentesquefermentummi.Etiamsedneque
# 1992
# sitametleoconsectetuersagittis.Nullafacilisi.Sedlobortis
# 1993
# eratvitaenulla.Duisbibendumipsumetmiscelerisquedapibus.
# 1994
# Fuscenonummyvestibulumorci.Donecanisl.Integeracnibh.
# 1995
# Pellentesquehabitantmorbitristiquesenectusetnetusetmalesuada
# 1996
# famesacturpisegestas.Aeneannecnuncsedduilobortis
# 47
#
# 1997
# vestibulum.Praesentmetusligula,auctorvitae,laciniased,
# 1998
# hendrerita,felis.Etiamsapien.Proinetsemvitaedolorsodales
# 1999
# venenatis.Integerluctusaliquamrisus.}
# 2000
# %{124}
# 2001
# \NewLipsumPar{Maecenasmimassa,fermentumeu,venenatis
# 2002
# et,cursusid,ipsum.Morbivehiculajustofaucibusmauris.Donec
# 2003
# nonneque.Fusceidmiutnequetinciduntposuere.Suspendissequis
# 2004
# enim.Crasporttitor.Sedquisvelit.Aliquamvelaugueatwisi
# 2005
# blanditsuscipit.Duisutjusto.Classaptenttacitisociosquad
# 2006
# litoratorquentperconubianostra,perinceptoshymenaeos.Etiam
# 2007
# bibendumwisiquisaugue.Nullaloremodio,sollicitudinvitae,
# 2008
# vehiculanec,dapibusultricies,purus.Invitaetellusatodio
# 2009
# cursuscongue.Quisquetincidunttempusmetus.Aeneanetnullanec
# 2010
# dolordapibusultricies.Phaselluscommodovulputatearcu.Sedenim.
# 2011
# Phasellusquisleo.Aliquamiaculis,turpisnecaliquetrutrum,pede
# 2012
# risusportadiam,idullamcorpereratestsederos.Fusce
# 2013
# ornare.}
# 2014
# %{125}
# 2015
# \NewLipsumPar{Suspendisseporta,dolorsedfringilla
# 2016
# ultrices,auguemaurisgravidadolor,velsollicitudinmagnaduisit
# 2017
# ametnunc.Maurismolliscondimentumrisus.Integeripsum.Quisque
# 2018
# malesuada,eratacdictumpulvinar,magnanislfermentumligula,
# 2019
# quiseuismodmaurisfelisnondiam.Nullamsapienturpis,rutrum
# 2020
# vel,condimentumac,bibendumvulputate,nulla.Vestibulumtortor
# 2021
# ipsum,fermentumegestas,placeratut,vulputateet,wisi.Aliquam
# 2022
# eratvolutpat.Donecconsequat,ligulasitamettinciduntaliquam,
# 2023
# nuncloremsagittisnunc,aullamcorpereratanteacfelis.Donec
# 2024
# eleifend.Nullamquamleo,lobortisnon,condimentumat,tempus
# 2025
# consectetuer,orci.Quisqueutlorem.Donecnisl.Loremipsumdolor
# 2026
# sitamet,consectetueradipiscingelit.Vestibulumanteipsumprimis
# 2027
# infaucibusorciluctusetultricesposuerecubiliaCurae;Donec
# 2028
# porta,liberoegetfeugiatposuere,felisarcupulvinarodio,vel
# 2029
# dapibusenimduinecturpis.}
# 2030
# %{126}
# 2031
# \NewLipsumPar{Duisleo.Crasnecodio.Nullampretium
# 2032
# laciniaest.Fuscealiquet,metusetvestibulumlobortis,anteerat
# 2033
# vestibulumeros,eusodaleserosturpisidmassa.Quisqueest.
# 2034
# Vivamuseulacus.Nullanisl.Nameros.Aliquamsitametnequevel
# 2035
# magnadictumultricies.Praesentmagnamauris,sollicitudinac,
# 2036
# commodoeu,bibendumsitamet,lectus.Suspendissepotenti.Fusce
# 2037
# congueleoquisliberononummyadipiscing.Vestibulumanteipsum
# 2038
# primisinfaucibusorciluctusetultricesposuerecubiliaCurae;
# 2039
# Nuncaorci.Utateratsitametnuncscelerisquemalesuada.
# 2040
# Phasellusodionisl,portaeget,laoreetnec,vehiculanon,risus.
# 2041
# Etiamdolormauris,consectetuereget,tinciduntsed,egestasquis,
# 2042
# neque.Utegestasanteaclibero.Proinmattisvolutpatmetus.}
# 2043
# %{127}
# 2044
# \NewLipsumPar{Sedtempormetusegetwisi.Duiscursus.Nam
# 2045
# nunc.Nullaplaceratwisisedest.Aeneanrisus.Loremipsumdolor
# 2046
# sitamet,consectetueradipiscingelit.Proineratdolor,ultricies
# 2047
# a,rutrumsed,posuereeget,metus.Donecsagittisnuncactortor.
# 2048
# Aliquameratvolutpat.Curabiturconsectetuer,auguenecviverra
# 2049
# eleifend,dolordolorvolutpatorci,dapibuspellentesqueerospede
# 2050
# aarcu.Nullamaugue.Etiamegetnullavelmiportahendrerit.
# 2051
# Phaselluscursusscelerisquetortor.Maecenasutleo.}
# 2052
# %{128}
# 2053
# \NewLipsumPar{Doneclibero.Quisquevitaeestquisdui
# 2054
# bibendumsuscipit.Fusceleofelis,sagittisnon,vehiculaac,
# 2055
# ultriciesvitae,diam.Aeneancongueliberoetmetus.Nulla
# 2056
# convallisliberoalacus.Donechendreritloremsitametleo.Mauris
# 2057
# libero.Pellentesquepulvinarmolestiedolor.Proinnibhmauris,
# 2058
# ornareat,pretiumsitamet,porttitorvel,mi.Pellentesque
# 2059
# habitantmorbitristiquesenectusetnetusetmalesuadafamesac
# 48
#
# 2060
# turpisegestas.}
# 2061
# %{129}
# 2062
# \NewLipsumPar{Vestibulumanteipsumprimisinfaucibusorci
# 2063
# luctusetultricesposuerecubiliaCurae;Aliquaminterdumporttitor
# 2064
# tortor.Donecultriciesjustoegetsapien.Proinacest.Aliquam
# 2065
# eratvolutpat.Intempusscelerisqueligula.Morbiscelerisqueurna.
# 2066
# Duisacnisl.Donecsedleo.Fusceposuereorcimollisnunc.Sed
# 2067
# arcuenim,pharetranec,aliquameu,consectetuersitamet,eros.
# 2068
# Sedidenim.Etiammattisestatelit.Pellentesqueestrisus,
# 2069
# pellentesquenec,dignissimvitae,egestasvitae,sapien.Maecenas
# 2070
# eterosnonliberoiaculisfacilisis.Maurisporttitortemporjusto.
# 2071
# Sedsollicitudinnequeneclibero.}
# 2072
# %{130}
# 2073
# \NewLipsumPar{Maurisacipsum.Duisultriceseratacfelis.
# 2074
# Donecdignissimluctusorci.Fuscepedeodio,feugiatsitamet,
# 2075
# aliquameu,viverraeleifend,ipsum.Fuscearcumassa,posuereid,
# 2076
# nonummyeu,pulvinarut,wisi.Seddui.Vestibulumnuncnisl,rutrum
# 2077
# quis,pharetraeget,conguesed,dui.Donecjustoneque,euismod
# 2078
# eget,nonummyadipiscing,iaculiseu,leo.Duislectus.Morbi
# 2079
# pellentesquenonummydui.}
# 2080
# %{131}
# 2081
# \NewLipsumPar{Aeneansemdolor,fermentumnec,gravida
# 2082
# hendrerit,mattiseget,felis.Nullamnondiamvitaemilacinia
# 2083
# consectetuer.Fuscenonmassaegetquamluctusposuere.Aenean
# 2084
# vulputatevelit.Quisqueetdolor.Donecipsumtortor,rutrumquis,
# 2085
# molliseu,mollisa,pede.Donecnulla.Duismolestie.Duislobortis
# 2086
# commodopurus.Pellentesquevelquam.Utcongueconguerisus.Sed
# 2087
# ligula.Aeneandictumpedevitaefelis.Donecsitametnibh.
# 2088
# Maecenaseuorci.Quisquegravidaquamsedmassa.}
# 2089
# %{132}
# 2090
# \NewLipsumPar{Nunceuismod,maurisluctusadipiscing
# 2091
# pellentesque,augueligulapellentesquelectus,vitaeposuerepurus
# 2092
# velitapede.Phasellusleomi,egestasimperdiet,blanditnon,
# 2093
# sollicitudinpharetra,enim.Nullamfaucibustellusnonenim.Sed
# 2094
# egestasnunceueros.Nunceuismodvenenatisurna.Phasellus
# 2095
# ullamcorper.Vivamusvariusestaclorem.Inidpedeeleifendnibh
# 2096
# consectetuerfaucibus.Phasellusaccumsaneuismodelit.Etiamvitae
# 2097
# elit.Integerimperdietnibh.Morbiimperdietorcieuismodmi.}
# 2098
# %{133}
# 2099
# \NewLipsumPar{Donectincidunttempormetus.Aenean
# 2100
# egestascursusnulla.Fusceacmetusatenimviverralacinia.
# 2101
# Vestibuluminmagnanonerosvariussuscipit.Nullamcursusnibh.
# 2102
# Maurisneque.Innuncquam,convallisvitae,posuerein,consequat
# 2103
# sed,wisi.Phasellusbibendumconsectetuermassa.Curabiturquis
# 2104
# urna.Pellentesqueajusto.}
# 2105
# %{134}
# 2106
# \NewLipsumPar{Insitametduiegetlacusrutrumaccumsan.
# 2107
# Phasellusacmetussedmassavariusauctor.Curabiturvelitelit,
# 2108
# pellentesqueeget,molestienec,congueat,pede.Maecenasquis
# 2109
# tellusnonloremvulputateornare.Vestibulumanteipsumprimisin
# 2110
# faucibusorciluctusetultricesposuerecubiliaCurae;Etiammagna
# 2111
# arcu,vulputateegestas,aliquetut,facilisisut,nisl.Donec
# 2112
# vulputatewisiacdolor.Aliquamfeugiatnibhidtellus.Morbieget
# 2113
# massasitametpurusaccumsandictum.Aeneanalorem.Fuscesemper
# 2114
# portasapien.}
# 2115
# %{135}
# 2116
# \NewLipsumPar{Curabitursitametliberoegetenimeleifend
# 2117
# lacinia.Vivamussagittisvolutpatdui.Suspendissepotenti.Morbia
# 2118
# nibheuauguefermentumposuere.Curabiturelitaugue,portaquis,
# 2119
# conguealiquam,rutrumnon,massa.Integermattismollisipsum.Sed
# 2120
# tellusenim,mattisid,feugiatsed,eleifendin,elit.Phasellus
# 2121
# nonpurussedelitviverrarhoncus.Vestibulumidtellusvelsem
# 2122
# imperdietcongue.Aeneaninarcu.Nullamurnajusto,imperdieteget,
# 49
#
# 2123
# volutpatvitae,sempereu,quam.Sedturpisdui,porttitorut,
# 2124
# egestasac,condimentumnon,wisi.Fusceiaculisturpisegetdui.
# 2125
# Quisquepulvinarestpellentesqueleo.Utnullaelit,mattisvel,
# 2126
# scelerisquevel,blanditut,justo.Nullafeugiatrisusin
# 2127
# erat.}
# 2128
# %{136}
# 2129
# \NewLipsumPar{Curabiturhendrerit.Morbifringillaenim
# 2130
# quisnunc.Phasellusatdui.Doneccommodoaugueatnunc.Nuncin
# 2131
# sapienetmagnamollissagittis.Morbieuelit.Phaselluslacus.
# 2132
# Donecaquam.Etiampulvinarsapien.Sednibhmagna,viverravitae,
# 2133
# auctoreget,eleifendnec,lorem.Curabiturfringilladuiaodio.
# 2134
# Nuncsempercondimentumarcu.Curabiturvitaelectussitametturpis
# 2135
# pretiumcondimentum.Nullamimperdietmattisneque.Proinegetmagna
# 2136
# portaeratrhoncusconsectetuer.Aeneanpulvinareratvitaemi.}
# 2137
# %{137}
# 2138
# \NewLipsumPar{Inegetturpisnontortoriaculis
# 2139
# tincidunt.Utegestasfeugiatmagna.Duisenimnibh,gravidavel,
# 2140
# nonummynon,sollicitudinac,enim.Sedintortorsedtellus
# 2141
# eleifendcursus.Morbiadoloratnibhmolestiefaucibus.Duissed
# 2142
# wisi.Duisfringilla,duietmalesuadadignissim,eliterosdictum
# 2143
# lacus,rhoncusimperdietpedeelitnectellus.Aeneanatligulaeget
# 2144
# nullaimperdietfaucibus.Quisquevestibulumloremacleo.Sed
# 2145
# laoreetnequeutmagna.}
# 2146
# %{138}
# 2147
# \NewLipsumPar{Aeneanegetjustoidloremcongue
# 2148
# tristique.Maecenassitametnunc.Aeneanbibendumrisus.Nam
# 2149
# convallis,misedultricessodales,metusnibhplaceratdui,eu
# 2150
# hendreriteratenimvellibero.Duisplaceratsemvitaewisi
# 2151
# imperdietcondimentum.Aliquampellentesqueduiacdiameleifend
# 2152
# venenatis.Nullafacilisisposueresapien.Craseuismod.Praesentut
# 2153
# enim.Aliquamutipsumquisurnainterdumvehicula.Fusceegetsem.
# 2154
# Nullamaccumsanullamcorperturpis.}
# 2155
# %{139}
# 2156
# \NewLipsumPar{Integerposuere,metusacrhoncusauctor,mi
# 2157
# tellusscelerisquenunc,venenatiselementumtortorloremeuerat.
# 2158
# Sedconsectetuerrisusvitaeorci.Nullamtortormauris,interdum
# 2159
# at,imperdietin,convalliseget,massa.Aliquamsuscipit,magnanec
# 2160
# blanditvolutpat,lectusnequesuscipitnunc,sitametcursusnisl
# 2161
# erategetrisus.Vestibulumleolectus,accumsanut,pharetravel,
# 2162
# elementumsed,quam.Maecenascondimentumorciatenim.Maecenasut
# 2163
# nunc.Vivamuspede.Integervelpurusvelmimollisvestibulum.Sed
# 2164
# laoreetultriciesnibh.Suspendissenonnislquisligulafermentum
# 2165
# facilisis.Vestibulumsemnibh,porttitoret,fermentuma,ultricies
# 2166
# id,augue.}
# 2167
# %{140}
# 2168
# \NewLipsumPar{Inaccumsanconvallismetus.Aeneanest.Donec
# 2169
# pharetraportaodio.Duisnuncnisl,imperdietac,tinciduntvitae,
# 2170
# variussitamet,felis.Curabiturwisi.Utiaculis,nuncinlacinia
# 2171
# egestas,elitenimtinciduntturpis,atluctusipsumaugue
# 2172
# condimentummetus.Aeneanloremwisi,cursussitamet,mollisnec,
# 2173
# portaac,augue.Vivamusmassa.Praesentrhoncusimperdietorci.
# 2174
# Aeneanpharetradolorutsapien.Maecenasegestasauguesemper
# 2175
# dolor.}
# 2176
# %{141}
# 2177
# \NewLipsumPar{Vestibulumatlectus.Vestibulumdapibus
# 2178
# placeratmagna.Suspendissedolorurna,condimentumsitamet,
# 2179
# euismoda,adipiscinga,enim.Aliquameratvolutpat.Donec
# 2180
# imperdietdolornonmi.Phasellusmagnametus,dictumsitamet,
# 2181
# laoreetnon,dictumvel,dui.Suspendissepotenti.Nuncturpis
# 2182
# risus,portavel,pharetraid,eleifendvitae,justo.Duispulvinar
# 2183
# dolorsitameturna.Integereueros.Nullafacilisi.Duisdui.
# 2184
# Nullamvitaequam.Morbianuncinelitsodaleseuismod.Nuncsed
# 2185
# orci.Etiammalesuadametusvitaefelis.Suspendisseimperdietvelit
# 50
#
# 2186
# intellus.}
# 2187
# %{142}
# 2188
# \NewLipsumPar{Nullamelitorci,condimentumvitae,accumsan
# 2189
# quis,gravidanon,velit.Morbipellentesqueaccumsanelit.Aenean
# 2190
# estpurus,eleifendac,dictumat,dignissimsed,dolor.Vestibulum
# 2191
# volutpatsapienquisaugue.Maecenasvulputateaccumsansapien.Nam
# 2192
# mattis,lacusnoniaculisaliquet,mielitvariuslectus,eu
# 2193
# malesuadadolornuncatwisi.Aliquamligula.Maurisnislelit,
# 2194
# molestievitae,gravidasitamet,facilisisconvallis,enim.Sed
# 2195
# urna.Praesentetaugue.Fuscepellentesque.Maecenasvariusorci
# 2196
# egetnisl.Donectemporrhoncusturpis.Integernibh.Crasmetus
# 2197
# erat,tinciduntet,scelerisquequis,bibendumsed,dui.Suspendisse
# 2198
# potenti.}
# 2199
# %{143}
# 2200
# \NewLipsumPar{Integeracdiam.Nullamporttitordoloreget
# 2201
# metus.Nullasedmetusquistortorlaciniatempor.Maurismauris
# 2202
# dui,faucibusvitae,aliquetsitamet,placerata,ante.Nunc
# 2203
# placerattinciduntneque.Maurisegestasdolorutipsumcursus
# 2204
# malesuada.Curabiturodio.Nunclobortis.Sedmattistemporfelis.
# 2205
# Maurisdolorquam,facilisisat,bibendumsitamet,rutrumornare,
# 2206
# pede.Suspendisseaccumsansagittisvelit.Pellentesquevarius
# 2207
# laoreetlorem.Vivamusegestassapieniddiam.}
# 2208
# %{144}
# 2209
# \NewLipsumPar{Integerviverra,felisactempuscursus,
# 2210
# nequerisusinterdumturpis,egetvenenatistellusvelitinneque.
# 2211
# Nullafeugiatluctustellus.Nampulvinarlacusidleo.Vestibulum
# 2212
# atligula.Duislaoreettinciduntenim.Suspendisseatnislmolestie
# 2213
# estlaoreetlaoreet.Suspendisseeuismodmetusvelnisl.Aenean
# 2214
# ullamcorperimperdietmassa.Aliquamnibh.Donecquiserat.Nunc
# 2215
# sodalesauctorante.}
# 2216
# %{145}
# 2217
# \NewLipsumPar{Namquisante.Nullaminterdumquamineros.
# 2218
# Sedeleifendliberoeutellusconsequatfermentum.Nullam
# 2219
# pellentesquerisusutaugue.Vestibulumeutellus.Integereleifend
# 2220
# suscipiturna.Fusceporttitorleoetodio.Vivamusvehiculajustoa
# 2221
# nisl.Inrutrum,purusutdictumauctor,dolorvelitaccumsandolor,
# 2222
# euconvallisaugueduiaclectus.Nullameleifendpellentesque
# 2223
# ligula.Namquismagna.Donecelementumdapibuserat.Pellentesque
# 2224
# velipsumnecorcifermentumaccumsan.Nuncportamagnaeuneque.
# 2225
# Namiderateumialiquetcursus.Morbiutfelis.Vestibulumin
# 2226
# ipsum.}
# 2227
# %{146}
# 2228
# \NewLipsumPar{Donecvelaugue.Morbiaturpissedlibero
# 2229
# consequatporta.Quisquelaciniaconsequatodio.Sedvehicula
# 2230
# sollicitudinpurus.Vestibulumegetest.Inhachabitasseplatea
# 2231
# dictumst.Sedblandit,tortoraauctorimperdiet,wisinibhornare
# 2232
# leo,acdictumnibhenimeuorci.Pellentesquehabitantmorbi
# 2233
# tristiquesenectusetnetusetmalesuadafamesacturpisegestas.
# 2234
# Aliquamtinciduntullamcorperjusto.Etiamaccumsanlacusnecante.
# 2235
# Utdictumluctusmauris.Utmetus.Maecenasgravida.Proiniaculis.
# 2236
# Integerconvallis,justoiaculisullamcorpersollicitudin,lectus
# 2237
# nequetinciduntmi,atcondimentumsemquamveldiam.Aeneansit
# 2238
# ametpurus.}
# 2239
# %{147}
# 2240
# \NewLipsumPar{Sedjusto.Maecenaslacinia,turpissed
# 2241
# commodocongue,odiournaelementumnunc,vitaemolestievelitnunc
# 2242
# eusem.Maecenasenim.Proinquisnequenectortorsollicitudin
# 2243
# volutpat.Sedatante.Sedvitaemaurisnonanteegestashendrerit.
# 2244
# Cumsociisnatoquepenatibusetmagnisdisparturientmontes,
# 2245
# nasceturridiculusmus.Invenenatisfacilisismagna.Phasellus
# 2246
# purus.Crasquismauris.Aliquamegetmagna.Donecrutrumsagittis
# 2247
# mi.Morbielementum,estsitametsollicitudinfeugiat,orcimagna
# 2248
# semperrisus,euconguenullametusvelelit.Nunctemporornaremi.
# 51
#
# 2249
# Integerjustoodio,suscipittincidunt,fermentumeu,tinciduntet,
# 2250
# libero.Vestibulumvestibulum,urnaetsuscipitimperdiet,nulla
# 2251
# antefermentumerat,atlaoreetloremlectussedmetus.Fusceante
# 2252
# sem,posuerein,vehiculaa,posueresed,ante.Phasellusmagna.
# 2253
# Maecenassitametdiam.Nuncatnibhsitametauguetristique
# 2254
# gravida.}
# 2255
# %{148}
# 2256
# \NewLipsumPar{Aeneanadipiscingauctorest.Morbiquam
# 2257
# arcu,malesuadased,volutpatet,elementumsitamet,libero.Duis
# 2258
# accumsan.Curabitururna.Insedipsum.Doneclobortisnibh.Duis
# 2259
# mattis.Sedcursuslectusquisodio.Phasellusarcu.Praesent
# 2260
# imperdietduiinsapien.Vestibulumtelluspede,auctora,
# 2261
# pellentesquesitamet,vulputatesed,purus.Nuncpulvinar,duiat
# 2262
# eleifendadipiscing,tellusnullaplaceratmassa,sedcondimentum
# 2263
# nullatellussedligula.Nullavitaeodiositametleoimperdiet
# 2264
# blandit.Invelmassa.Maecenasvariusduiatturpis.Sedodio.}
# 2265
# %{149}
# 2266
# \NewLipsumPar{Quisquealiquamipsumsedturpis.
# 2267
# Pellentesquelaoreetvelitnecjusto.Namsedaugue.Maecenasrutrum
# 2268
# quameudolor.Fusceconsectetuer.Prointellusest,luctusvitae,
# 2269
# molestiea,mattiset,mauris.Donectempor.Pellentesquehabitant
# 2270
# morbitristiquesenectusetnetusetmalesuadafamesacturpis
# 2271
# egestas.Duisantefelis,dignissimid,blanditin,suscipitvel,
# 2272
# dolor.Pellentesquetinciduntcursusfelis.Proinrhoncussemper
# 2273
# nulla.Utetest.Vivamusipsumerat,gravidain,venenatisac,
# 2274
# fringillain,quam.Nuncacaugue.Fuscepedeerat,ultricesnon,
# 2275
# consequatet,sempersitamet,urna.}
# 2276
# %{150}
# 2277
# \NewLipsumPar{Fusceadipiscingjustonecante.Nullaminenim.
# 2278
# Pellentesquefelisorci,sagittisac,malesuadaet,facilisisin,
# 2279
# ligula.Nuncnonmagnasitametmialiquamdictum.Inmi.Curabitur
# 2280
# sollicitudinjustosedquam.Aeneanimperdiet.Vestibulumanteipsum
# 2281
# primisinfaucibusorciluctusetultricesposuerecubiliaCurae;
# 2282
# Doneclacinianonummylectus.Proinvelurna.Fuscesitametorciac
# 2283
# magnaiaculispharetra.Duissagittismassaintellus.Aeneanvel
# 2284
# velitvelfelisconsectetuerpharetra.}
# 2285
# h
# =
# lipsum
# i
# 52
#
# 7.2ThetextofCicero'sspeech
# 2286
# h
# *
# cicero
# i
# 2287
# 2288
# %%
# 2289
# %%Thistextwasprovidedbygithub-user
# 2290
# %%svenper.Seehttps://github.com/patta42/lipsum/issues/13
# 2291
# %%
# 2292
# 2293
# \NewLipsumPar{Noneramnescius,Brute,cum,quaesummisingeniisexquisitaque
# 2294
# doctrinaphilosophiGraecosermonetractavissent,eaLatinislitteris
# 2295
# mandaremus,foreuthicnosterlaborinvariasreprehensionesincurreret.Nam
# 2296
# quibusdam,etiisquidemnonadmodumindoctis,totumhocdisplicet
# 2297
# philosophari.Quidamautemnontamidreprehendunt,siremissiusagatur,sed
# 2298
# tantumstudiumtamquemultamoperamponendamineononarbitrantur.Erunt
# 2299
# etiam,etiiquidemeruditiGraecislitteris,contemnentesLatinas,quise
# 2300
# dicantinGraecislegendisoperammalleconsumere.Postremoaliquosfuturos
# 2301
# suspicor,quimeadaliaslitterasvocent,genushocscribendi,etsisit
# 2302
# elegans,personaetamenetdignitatisessenegent.}
# 2303
# %{2}
# 2304
# \NewLipsumPar{Contraquosomnisdicendumbreviterexistimo.Quamquam
# 2305
# philosophiaequidemvituperatoribussatisresponsumesteolibro,quoanobis
# 2306
# philosophiadefensaetcollaudataest,cumessetaccusataetvituperataab
# 2307
# Hortensio.Quilibercumettibiprobatusvidereturetiis,quosegoposse
# 2308
# iudicarearbitrarer,plurasuscepiveritusnemoverehominumstudiaviderer,
# 2309
# retinerenonposse.Quiautem,simaximehocplaceat,moderatiustamenid
# 2310
# voluntfieri,difficilemquandamtemperantiampostulantineo,quodsemel
# 2311
# admissumcoercerireprimiquenonpotest,utpropemodumiustioribusutamur
# 2312
# illis,quiomninoavocentaphilosophia,quamhis,quirebusinfinitismodum
# 2313
# constituantinrequeeomeliore,quomaiorsit,mediocritatemdesiderent.}
# 2314
# %{3}
# 2315
# \NewLipsumPar{Siveenimadsapientiamperveniripotest,nonparandanobis
# 2316
# solumea,sedfruendaetiam[sapientia]est;sivehocdifficileest,tamennec
# 2317
# modusestullusinvestigandiveri,nisiinveneris,etquaerendidefatigatio
# 2318
# turpisest,cumid,quodquaeritur,sitpulcherrimum.Etenimsidelectamur,
# 2319
# cumscribimus,quisesttaminvidus,quiabeonosabducat?Sinlaboramus,
# 2320
# quisest,quialienaemodumstatuatindustriae?NamutTerentianusChremesnon
# 2321
# inhumanus,quinovumvicinumnonvult\textquoteleftfodereautarareaut
# 2322
# aliquidferredenique\textquoteright\space\textendash\spacenonenimillumab
# 2323
# industria,sedabinliberalilaboredeterret\textendash,sicisticuriosi,
# 2324
# quosoffenditnosterminimenobisiniucunduslabor.}
# 2325
# %{4}
# 2326
# \NewLipsumPar{Iisigiturestdifficiliussatisfacere,quiseLatinascripta
# 2327
# dicuntcontemnere.Inquibushocprimumestinquoadmirer,curingravissimis
# 2328
# rebusnondelecteteossermopatrius,cumidemfabellasLatinasadverbume
# 2329
# Graecisexpressasnoninvitilegant.Quisenimtaminimicuspaenenomini
# 2330
# Romanoest,quiEnniiMedeamautAntiopamPacuviispernatautreiciat,quodse
# 2331
# isdemEuripidisfabulisdelectaridicat,Latinaslitterasoderit?}
# 2332
# %{5}
# 2333
# \NewLipsumPar{Synephebosego,inquit,potiusCaeciliiautAndriamTerentii
# 2334
# quamutramqueMenandrilegam?}
# 2335
# %{6}
# 2336
# \NewLipsumPar{Aquibustantumdissentio,ut,cumSophoclesveloptime
# 2337
# scripseritElectram,tamenmaleconversamAtiliimihilegendamputem,dequo
# 2338
# Lucilius:\textquoteleftferreumscriptorem\textquoteright,verum,opinor,
# 2339
# scriptoremtamen,utlegendussit.Rudemenimesseomninoinnostrispoetis
# 2340
# autinertissimaesegnitiaeestautfastidiidelicatissimi.Mihiquidemnulli
# 2341
# satiseruditividentur,quibusnostraignotasunt.An\textquoteleftUtinamne
# 2342
# innemore\ldots\textquoteright\spacenihilominuslegimusquamhocidem
# 2343
# Graecum,quaeautemdebenebeatequevivendoaPlatonedisputatasunt,haec
# 2344
# explicarinonplacebitLatine?}
# 2345
# %{7}
# 2346
# \NewLipsumPar{Quid?Sinosnoninterpretumfungimurmunere,sedtuemurea,
# 2347
# quaedictasuntabiisquosprobamus,eisquenostrumiudiciumetnostrum
# 53
#
# 2348
# scribendiordinemadiungimus,quidhabent,curGraecaanteponantiis,quaeet
# 2349
# splendidedictasintnequesintconversadeGraecis?Namsidicentabillis
# 2350
# hasresessetractatas,neipsosquidemGraecosestcurtammultoslegant,
# 2351
# quamlegendisunt.QuidenimestaChrysippopraetermissuminStoicis?Legimus
# 2352
# tamenDiogenem,Antipatrum,Mnesarchum,Panaetium,multosaliosinprimisque
# 2353
# familiaremnostrumPosidonium.Quid?Theophrastusmediocriternedelectat,cum
# 2354
# tractatlocosabAristoteleantetractatos?Quid?Epicureinumdesistuntde
# 2355
# isdem,dequibusetabEpicuroscriptumestetabantiquis,adarbitriumsuum
# 2356
# scribere?QuodsiGraecilegunturaGraecisisdemderebusaliaratione
# 2357
# compositis,quidest,curnostrianostrisnonlegantur?}
# 2358
# %{8}
# 2359
# \NewLipsumPar{Quamquam,siplanesicverteremPlatonemautAristotelem,ut
# 2360
# verteruntnostripoetaefabulas,male,credo,merererdemeiscivibus,siad
# 2361
# eorumcognitionemdivinaillaingeniatransferrem.Sedidnequefeciadhucnec
# 2362
# mihitamen,nefaciam,interdictumputo.Locosquidemquosdam,sividebitur,
# 2363
# transferam,etmaximeabiis,quosmodonominavi,cuminciderit,utidapte
# 2364
# fieripossit,utabHomeroEnnius,AfraniusaMenandrosolet.Necvero,ut
# 2365
# nosterLucilius,recusabo,quominusomnesmealegant.Utinamessetille
# 2366
# Persius,ScipioveroetRutiliusmultoetiammagis,quorumilleiudicium
# 2367
# reformidansTarentinisaitseetConsentinisetSiculisscribere.Faceteis
# 2368
# quidem,sicutalia;sednequetamdoctitumerant,adquorumiudicium
# 2369
# elaboraret,etsuntilliusscriptaleviora,uturbanitassummaappareat,
# 2370
# doctrinamediocris.}
# 2371
# %{9}
# 2372
# \NewLipsumPar{Egoautemquemtimeamlectorem,cumadteneGraecisquidem
# 2373
# cedenteminphilosophiaaudeamscribere?Quamquamateipsoidquidemfacio
# 2374
# provocatusgratissimomihilibro,quemadmedevirtutemisisti.Sedexeo
# 2375
# credoquibusdamusuvenire;utabhorreantaLatinis,quodinciderintin
# 2376
# incultaquaedamethorrida,demalisGraecisLatinescriptadeterius.Quibus
# 2377
# egoassentior,dummododeisdemrebusneGraecosquidemlegendosputent.Res
# 2378
# verobonasverbiselectisgraviterornatequedictasquisnonlegat?Nisiqui
# 2379
# seplaneGraecumdicivelit,utaScaevolaestpraetoresalutatusAthenis
# 2380
# Albucius.}
# 2381
# %{10}
# 2382
# \NewLipsumPar{Quemquidemlocumcomitmultavenustateetomnisaleidem
# 2383
# Lucilius,apudquempraeclareScaevola:}
# 2384
# %{11}
# 2385
# \NewLipsumPar{Graecumte,Albuci,quamRomanumatqueSabinum,municipemPonti,
# 2386
# Tritani,centurionum,praeclarorumhominumacprimorumsigniferumque,maluisti
# 2387
# dici.GraeceergopraetorAthenis,idquodmaluisti,te,cumadmeaccedis,
# 2388
# saluto:\textquoteleft[\ldots],\textquoteright\spaceinquam,\textquoteleft
# 2389
# Tite!\textquoteright\spacelictores,turmaomnischorusque:
# 2390
# \textquoteleft[\ldots],Tite!\textquoteright\spacehinchostismiAlbucius,
# 2391
# hincinimicus.}
# 2392
# %{12}
# 2393
# \NewLipsumPar{SediureMucius.Egoautemmirari[satis]nonqueoundehocsit
# 2394
# taminsolensdomesticarumrerumfastidium.Nonestomninohicdocendilocus;
# 2395
# seditasentioetsaepedisserui,Latinamlinguamnonmodononinopem,ut
# 2396
# vulgoputarent,sedlocupletioremetiamessequamGraecam.Quandoenimnobis,
# 2397
# veldicamautoratoribusbonisautpoetis,posteaquidemquamfuitquem
# 2398
# imitarentur,ullusorationisvelcopiosaevelelegantisornatusdefuit?Ego
# 2399
# vero,quoniamforensibusoperis,laboribus,periculisnondeseruissemihi
# 2400
# videorpraesidium,inquoapopuloRomanolocatussum,debeoprofecto,
# 2401
# quantumcumquepossum,ineoquoqueelaborare,utsintopera,studio,labore
# 2402
# meodoctiorescivesmei,neccumististantoperepugnare,quiGraecalegere
# 2403
# malint,modolegantillaipsa,nesimulent,etiisservire,quivelutrisque
# 2404
# litterisutivelintvel,sisuashabent,illasnonmagnoperedesiderent.}
# 2405
# %{13}
# 2406
# \NewLipsumPar{Quiautemaliamaluntscribianobis,aequiessedebent,quodet
# 2407
# scriptamultasunt,sicutpluraneminienostris,etscribenturfortasse
# 2408
# plura,sivitasuppetet;ettamen,quidiligenterhaec,quaedephilosophia
# 2409
# litterismandamus,legereassueverit,iudicabitnullaadlegendumhisesse
# 2410
# potiora.Quidesteniminvitatantoperequaerendumquamcumomniain
# 54
#
# 2411
# philosophia,tumid,quodhislibrisquaeritur,quisitfinis,quidextremum,
# 2412
# quidultimum,quosintomniabenevivendirectequefaciendiconsilia
# 2413
# referenda,quidsequaturnaturautsummumexrebusexpetendis,quidfugiatut
# 2414
# extremummalorum?Quaderecumsitinterdoctissimossummadissensio,quis
# 2415
# alienumputeteiusessedignitatis,quammihiquisquetribuat,quidinomni
# 2416
# munerevitaeoptimumetverissimumsit,exquirere?}
# 2417
# %{14}
# 2418
# \NewLipsumPar{An,partusancillaesitneinfructuhabendus,dissereturinter
# 2419
# principescivitatis,P.ScaevolamM\textquoteright.queManilium,abiisqueM.
# 2420
# Brutusdissentiet\textendash\spacequodetacutumgenusestetadususcivium
# 2421
# noninutile,nosqueeascriptareliquaqueeiusdemgenerisetlegimuslibenter
# 2422
# etlegemus\textendash,haec,quaevitamomnemcontinent,neglegentur?Nam,ut
# 2423
# sintillavendibiliora,haecuberioracertesunt.Quamquamidquidemlicebit
# 2424
# iisexistimare,quilegerint.Nosautemhancomnemquaestionemdefinibus
# 2425
# bonorumetmalorumfereanobisexplicatamessehislitterisarbitramur,in
# 2426
# quibus,quantumpotuimus,nonmodoquidnobisprobaretur,sedetiamquida
# 2427
# singulisphilosophiaedisciplinisdiceretur,persecutisumus.}
# 2428
# %{15}
# 2429
# \NewLipsumPar{Utautemafacillimisordiamur,primaveniatinmediumEpicuri
# 2430
# ratio,quaeplerisquenotissimaest.Quamanobissicintellegeseitam,utab
# 2431
# ipsis,quieamdisciplinamprobant,nonsoleataccuratiusexplicari;verum
# 2432
# eniminvenirevolumus,nontamquamadversariumaliquemconvincere.Accurate
# 2433
# autemquondamaL.Torquato,homineomnidoctrinaerudito,defensaestEpicuri
# 2434
# sententiadevoluptate,amequeeiresponsum,cumC.Triarius,inprimis
# 2435
# gravisetdoctusadolescens,eidisputationiinteresset.}
# 2436
# %{16}
# 2437
# \NewLipsumPar{NamcumadmeinCumanumsalutandicausauterquevenisset,pauca
# 2438
# primointernosdelitteris,quarumsummumeratinutroquestudium,deinde
# 2439
# Torquatus:Quoniamnactite,inquit,sumusaliquandootiosum,certeaudiam,
# 2440
# quidsit,quodEpicurumnostrumnontuquidemoderis,utferefaciunt,quiab
# 2441
# eodissentiunt,sedcertenonprobes,eumquemegoarbitrorunumvidisseverum
# 2442
# maximisqueerroribusanimoshominumliberavisseetomniatradidisse,quae
# 2443
# pertinerentadbenebeatequevivendum.Sedexistimote,sicutnostrum
# 2444
# Triarium,minusabeodelectari,quodistaPlatonis,Aristoteli,Theophrasti
# 2445
# orationisornamentaneglexerit.Namilludquidemadducivixpossum,utea,
# 2446
# quaesenseritille,tibinonveravideantur.}
# 2447
# %{17}
# 2448
# \NewLipsumPar{Vide,quantum,inquam,fallare,Torquate.Oratiomeistius
# 2449
# philosophinonoffendit;nametcomplectiturverbis,quodvult,etdicit
# 2450
# plane,quodintellegam;ettamenegoaphilosopho,siafferateloquentiam,non
# 2451
# asperner,sinonhabeat,nonadmodumflagitem.Remihinonaequesatisfacit,
# 2452
# etquidemlocispluribus.Sedquothomines,totsententiae;falliigitur
# 2453
# possumus.}
# 2454
# %{18}
# 2455
# \NewLipsumPar{Quamobremtandem,inquit,nonsatisfacit?Teenimiudicem
# 2456
# aequumputo,modoquaedicatillebenenoris.}
# 2457
# %{19}
# 2458
# \NewLipsumPar{NisimihiPhaedrum,inquam,tumentitumautZenonemputas,
# 2459
# quorumutrumqueaudivi,cummihinihilsanepraetersedulitatemprobarent,
# 2460
# omnesmihiEpicurisententiaesatisnotaesunt.Atqueeos,quosnominavi,cum
# 2461
# Atticonostrofrequenteraudivi,cummirareturillequidemutrumque,Phaedrum
# 2462
# autemetiamamaret,cotidiequeinternosea,quaeaudiebamus,conferebamus,
# 2463
# nequeeratumquamcontroversia,quidegointellegerem,sedquidprobarem.}
# 2464
# %{20}
# 2465
# \NewLipsumPar{Quidigiturest?Inquit;audireenimcupio,quidnonprobes.
# 2466
# Principio,inquam,inphysicis,quibusmaximegloriatur,primumtotusest
# 2467
# alienus.Democriteadicitperpaucamutans,sedita,utea,quaecorrigere
# 2468
# vult,mihiquidemdepravarevideatur.Illeatomosquasappellat,idest
# 2469
# corporaindividuaproptersoliditatem,censetininfinitoinani,inquonihil
# 2470
# necsummumnecinfimumnecmediumnecultimumnecextremumsit,itaferri,ut
# 2471
# concursionibusintersecohaerescant,exquoefficianturea,quaesintquaeque
# 2472
# cernantur,omnia,eumquemotumatomorumnulloaprincipio,sedexaeterno
# 2473
# temporeintellegiconvenire.}
# 55
#
# 2474
# %{21}
# 2475
# \NewLipsumPar{Epicurusautem,inquibussequiturDemocritum,nonferelabitur.
# 2476
# Quamquamutriusquecummultanonprobo,tumilludinprimis,quod,cumin
# 2477
# rerumnaturaduoquaerendasint,unum,quaemateriasit,exquaquaequeres
# 2478
# efficiatur,alterum,quaevissit,quaequidqueefficiat,demateria
# 2479
# disseruerunt,vimetcausamefficiendireliquerunt.Sedhoccommunevitium,
# 2480
# illaeEpicuripropriaeruinae:censetenimeademillaindividuaetsolida
# 2481
# corporaferrideorsumsuopondereadlineam,huncnaturalemesseomnium
# 2482
# corporummotum.}
# 2483
# %{22}
# 2484
# \NewLipsumPar{Deindeibidemhomoacutus,cumilludocurreret,siomniadeorsus
# 2485
# eregioneferrenturet,utdixi,adlineam,numquamforeutatomusaltera
# 2486
# alterampossetattingereitaque**attulitremcommenticiam:declinaredixit
# 2487
# atomumperpaulum,quonihilpossetfieriminus;itaefficicomplexioneset
# 2488
# copulationesetadhaesionesatomoruminterse,exquoefficereturmundus
# 2489
# omnesquepartesmundi,quaequeineoessent.Quaecumtotares(est)ficta
# 2490
# pueriliter,tumneefficit[quidem],quodvult.Nametipsadeclinatioad
# 2491
# libidinemfingitur\textendash\spaceaitenimdeclinareatomumsinecausa;quo
# 2492
# nihilturpiusphysico,quamfieriquicquamsinecausadicere,
# 2493
# \textendash\spaceetillummotumnaturalemomniumponderum,utipse
# 2494
# constituit,eregioneinferioremlocumpetentiumsinecausaeripuitatomisnec
# 2495
# tamenid,cuiuscausahaecfinxerat,assecutusest.}
# 2496
# %{23}
# 2497
# \NewLipsumPar{Namsiomnesatomideclinabunt,nullaeumquamcohaerescent,sive
# 2498
# aliaedeclinabunt,aliaesuonuturecteferentur,primumerithocquasi,
# 2499
# provinciasatomisdare,quaerecte,quaeobliqueferantur,deindeeademilla
# 2500
# atomorum,inquoetiamDemocritushaeret,turbulentaconcursiohuncmundi
# 2501
# ornatumefficerenonpoterit.Neilludquidemphysici,crederealiquidesse
# 2502
# minimum,quodprofectonumquamputavisset,siaPolyaeno,familiarisuo,
# 2503
# geometricadisceremaluissetquamillumetiamipsumdedocere.SolDemocrito
# 2504
# magnusvidetur,quippehominieruditoingeometriaqueperfecto,huicpedalis
# 2505
# fortasse;tantumenimessecenset,quantusvidetur,velpauloautmaioremaut
# 2506
# minorem.}
# 2507
# %{24}
# 2508
# \NewLipsumPar{Ita,quaemutat,eacorrumpit,quaesequitursunttota
# 2509
# Democriti,atomi,inane,imagines,quae[\ldots]nominant,quorumincursione
# 2510
# nonsolumvideamus,sedetiamcogitemus;infinitioipsa,quam[\ldots]vocant,
# 2511
# totaabilloest,tuminnumerabilesmundi,quietorianturetintereant
# 2512
# cotidie.Quaeetsimihinullomodoprobantur,tamenDemocritumlaudatuma
# 2513
# ceterisabhoc,quieumunumsecutusesset,nollemvituperatum.}
# 2514
# %{25}
# 2515
# \NewLipsumPar{Iaminalteraphilosophiaeparte.Quaeestquaerendiac
# 2516
# disserendi,quae[\ldots]dicitur,istevesterplane,utmihiquidemvidetur,
# 2517
# inermisacnudusest.Tollitdefinitiones,nihildedividendoacpartiendo
# 2518
# docet,nonquomodoefficiaturconcludaturqueratiotradit,nonquavia
# 2519
# captiosasolvanturambiguadistinguanturostendit;iudiciareruminsensibus
# 2520
# ponit,quibussisemelaliquidfalsiproveroprobatumsit,sublatumesseomne
# 2521
# iudiciumverietfalsiputat.}
# 2522
# %{26}
# 2523
# \NewLipsumPar{Confirmatautemilludvelmaxime,quodipsanatura,utaitille,
# 2524
# sciscatetprobet,idestvoluptatemetdolorem.Adhaecetquaesequamuret
# 2525
# quaefugiamusrefertomnia.QuodquamquamAristippiestaCyrenaicisquemelius
# 2526
# liberiusquedefenditur,tameneiusmodiesseiudico,utnihilhominevideatur
# 2527
# indignius.Admaioraenimquaedamnosnaturagenuitetconformavit,utmihi
# 2528
# quidemvidetur.Acfieripotest,uterrem,seditaprorsusexistimo,nequeeum
# 2529
# Torquatum,quihocprimuscognomeninvenerit,auttorquemillumhosti
# 2530
# detraxisse,utaliquamexeoperciperetcorporevoluptatem,autcumLatinis
# 2531
# tertioconsulatuconflixisseapudVeserimproptervoluptatem;quodverosecuri
# 2532
# percussitfilium,privavisseseetiamvideturmultisvoluptatibus,cumipsi
# 2533
# naturaepatrioqueamoripraetuleritiusmaiestatisatqueimperii.}
# 2534
# %{27}
# 2535
# \NewLipsumPar{Quid?T.Torquatus,isquiconsulcumCn.\Octaviofuit,cum
# 2536
# illamseveritatemineofilioadhibuit,queminadoptionemD.Silano
# 56
#
# 2537
# emancipaverat,uteumMacedonumlegatisaccusantibus,quodpecuniaspraetorem
# 2538
# inprovinciacepissearguerent,causamapudsedicereiuberetrequeexutraque
# 2539
# parteauditapronuntiareteumnontalemviderifuisseinimperio,qualeseius
# 2540
# maioresfuissent,etinconspectumsuumvenirevetuit,numquidtibivideturde
# 2541
# voluptatibussuiscogitavisse?}
# 2542
# %{28}
# 2543
# \NewLipsumPar{Sedutomittampericula,labores,doloremetiam,quemoptimus
# 2544
# quisquepropatriaetprosuissuscipit,utnonmodonullamcaptet,sedetiam
# 2545
# praetereatomnesvoluptates,doloresdeniquequosvissusciperemalitquam
# 2546
# deserereullamofficiipartem,adea,quaehocnonminusdeclarant,sed
# 2547
# videnturleviora,veniamus.}
# 2548
# %{29}
# 2549
# \NewLipsumPar{Quidtibi,Torquate,quidhuicTriariolitterae,quidhistoriae
# 2550
# cognitioquererum,quidpoetarumevolutio,quidtantatotversuummemoria
# 2551
# voluptatisaffert?Necmihiilluddixeris:\textquoteleftHaecenimipsamihi
# 2552
# suntvoluptati,eterantillaTorquatis.\textquoteright\spaceNumquamhocita
# 2553
# defenditEpicurusnequeMetrodorusautquisquameorum,quiautsaperetaliquid
# 2554
# autistadidicisset.Etquodquaeritursaepe,curtammultisintEpicurei,
# 2555
# suntaliaequoquecausae,sedmultitudinemhaecmaximeallicit,quodita
# 2556
# putantdiciabillo,rectaethonestaquaesint,eafacereipsaperse
# 2557
# laetitiam,idestvoluptatem.Hominesoptiminonintellegunttotamrationem
# 2558
# everti,siitaressehabeat.Namsiconcederetur,etiamsiadcorpusnihil
# 2559
# referatur,istasuasponteetperseesseiucunda,perseessetetvirtuset
# 2560
# cognitiorerum,quodminimeillevultexpetenda.}
# 2561
# %{30}
# 2562
# \NewLipsumPar{HaecigiturEpicurinonprobo,inquam.Deceterovellemequidem
# 2563
# autipsedoctrinisfuissetinstructior\textendash\spaceestenim,quodtibi
# 2564
# itaviderinecesseest,nonsatispolitusiisartibus,quasquitenent,
# 2565
# eruditiappellantur\textendash\spaceautnedeterruissetaliosastudiis.
# 2566
# Quamquamtequidemvideominimeessedeterritum.}
# 2567
# %{31}
# 2568
# \NewLipsumPar{Quaecumdixissem,magisutillumprovocaremquamutipse
# 2569
# loquerer,tumTriariusleniterarridens:Tuquidem,inquit,totumEpicurum
# 2570
# paeneephilosophorumchorosustulisti.Quideireliquisti,nisite,quoquo
# 2571
# modoloqueretur,intellegere,quiddiceret?Alienadixitinphysicisnecea
# 2572
# ipsa,quaetibiprobarentur;siquainiiscorrigerevoluit,deteriorafecit.
# 2573
# Disserendiartemnullamhabuit.Voluptatemcumsummumbonumdiceret,primumin
# 2574
# eoipsoparumvidit,deindehocquoquealienum;namanteAristippus,etille
# 2575
# melius.Addidistiadextremumetiamindoctumfuisse.}
# 2576
# %{32}
# 2577
# \NewLipsumPar{Fieri,inquam,Triari,nullopactopotest,utnondicas,quid
# 2578
# nonprobeseius,aquodissentias.QuidenimmeprohiberetEpicureumesse,si
# 2579
# probarem,quaeillediceret?Cumpraesertimillaperdiscereludusesset.Quam
# 2580
# obremdissentientiumintersereprehensionesnonsuntvituperandae,
# 2581
# maledicta,contumeliae,tumiracundiae,contentionesconcertationesquein
# 2582
# disputandopertinacesindignaephilosophiamihividerisolent.}
# 2583
# %{33}
# 2584
# \NewLipsumPar{TumTorquatus:Prorsus,inquit,assentior;nequeenimdisputari
# 2585
# sinereprehensioneneccumiracundiaautpertinaciarectedisputaripotest.
# 2586
# Sedadhaec,nisimolestumest,habeoquaevelim.Anme,inquam,nisite
# 2587
# audirevellem,censeshaecdicturumfuisse?Utrumigiturpercurriomnem
# 2588
# Epicuridisciplinamplacetandeunavoluptatequaeri,dequaomnecertamen
# 2589
# est?Tuoveroidquidem,inquam,arbitratu.Sicfaciamigitur,inquit:unam
# 2590
# remexplicabo,eamquemaximam,dephysicisalias,etquidemtibiet
# 2591
# declinationemistamatomorumetmagnitudinemsolisprobaboetDemocritierrata
# 2592
# abEpicuroreprehensaetcorrectapermulta.Nuncdicamdevoluptate,nihil
# 2593
# scilicetnovi,eatamen,quaeteipsumprobaturumesseconfidam.}
# 2594
# %{34}
# 2595
# \NewLipsumPar{Certe,inquam,pertinaxnonerotibique,simihiprobabisea,
# 2596
# quaedices,libenterassentiar.Probabo,inquit,modoistasisaequitate,quam
# 2597
# ostendis.Sedutiorationeperpetuamaloquaminterrogareautinterrogari.Ut
# 2598
# placet,inquam.Tumdicereexorsusest.Primumigitur,inquit,sicagam,ut
# 2599
# ipsiauctorihuiusdisciplinaeplacet:constituam,quidetqualesitid,de
# 57
#
# 2600
# quoquaerimus,nonquoignorarevosarbitrer,sedutrationeetviaprocedat
# 2601
# oratio.Quaerimusigitur,quidsitextremumetultimumbonorum,quodomnium
# 2602
# philosophorumsententiataledebetesse,utadidomniareferrioporteat,
# 2603
# ipsumautemnusquam.HocEpicurusinvoluptateponit,quodsummumbonumesse
# 2604
# vult,summumquemalumdolorem,idqueinstituitdoceresic:}
# 2605
# %{35}
# 2606
# \NewLipsumPar{Omneanimal,simulatquenatumsit,voluptatemappetereeaque
# 2607
# gaudereutsummobono,doloremaspernariutsummummalumet,quantumpossit,a
# 2608
# serepellere,idquefacerenondumdepravatumipsanaturaincorrupteatque
# 2609
# integreiudicante.Itaquenegatopusesserationenequedisputatione,quamob
# 2610
# remvoluptasexpetenda,fugiendusdolorsit.Sentirihaecputat,utcalere
# 2611
# ignem,nivemessealbam,dulcemel.Quorumnihiloportereexquisitis
# 2612
# rationibusconfirmare,tantumsatisesseadmonere.Interesseeniminter
# 2613
# argumentumconclusionemquerationisetintermediocremanimadversionematque
# 2614
# admonitionem.Alteraoccultaquaedametquasiinvolutaaperiri,alteraprompta
# 2615
# etapertaiudicari.Etenimquoniamdetractisdehominesensibusreliquinihil
# 2616
# est,necesseest,quidautadnaturamautcontrasit,anaturaipsaiudicari.
# 2617
# Eaquidpercipitautquidiudicat,quoautpetatautfugiataliquid,praeter
# 2618
# voluptatemetdolorem?}
# 2619
# %{36}
# 2620
# \NewLipsumPar{Suntautemquidamenostris,quihaecsubtiliusvelinttradere
# 2621
# etnegentsatisesse,quidbonumsitautquidmalum,sensuiudicari,sedanimo
# 2622
# etiamacrationeintellegiposseetvoluptatemipsamperseesseexpetendamet
# 2623
# doloremipsumperseessefugiendum.Itaqueaiunthancquasinaturalematque
# 2624
# insitaminanimisnostrisinessenotionem,utalterumesseappetendum,alterum
# 2625
# aspernandumsentiamus.Aliiautem,quibusegoassentior,cumaphilosophis
# 2626
# compluribuspermultadicantur,curnecvoluptasinbonissitnumerandanecin
# 2627
# malisdolor,nonexistimantoporterenimiumnoscausaeconfidere,sedet
# 2628
# argumentandumetaccuratedisserendumetrationibusconquisitisdevoluptate
# 2629
# etdoloredisputandumputant.}
# 2630
# %{37}
# 2631
# \NewLipsumPar{Sedutperspiciatis,undeomnisistenatuserrorsitvoluptatem
# 2632
# accusantiumdoloremquelaudantium,totamremaperiameaqueipsa,quaeabillo
# 2633
# inventoreveritatisetquasiarchitectobeataevitaedictasunt,explicabo.
# 2634
# Nemoenimipsamvoluptatem,quiavoluptassit,aspernaturautoditautfugit,
# 2635
# sedquiaconsequunturmagnidoloreseos,quirationevoluptatemsequi
# 2636
# nesciunt,nequeporroquisquamest,quidoloremipsum,quiadolorsit,amet,
# 2637
# consectetur,adipiscivelit,sedquianonnumquameiusmoditemporaincidunt,
# 2638
# utlaboreetdoloremagnamaliquamquaeratvoluptatem.Utenimadminima
# 2639
# veniam,quisnostrumexercitationemullamcorporissuscipitlaboriosam,nisi
# 2640
# utaliquidexeacommodiconsequatur?Quisautemveleumiurereprehenderit,
# 2641
# quiineavoluptatevelitesse,quamnihilmolestiaeconsequatur,velillum,
# 2642
# quidoloremeumfugiat,quovoluptasnullapariatur?}
# 2643
# %{38}
# 2644
# \NewLipsumPar{Atveroeosetaccusamusetiustoodiodignissimosducimus,qui
# 2645
# blanditiispraesentiumvoluptatumdelenitiatquecorrupti,quosdoloreset
# 2646
# quasmolestiasexcepturisint,obcaecaticupiditatenonprovident,similique
# 2647
# suntinculpa,quiofficiadeseruntmollitiaanimi,idestlaborumetdolorum
# 2648
# fuga.Etharumquidemrerumfacilisestetexpeditadistinctio.Namlibero
# 2649
# tempore,cumsolutanobisesteligendioptio,cumquenihilimpedit,quominus
# 2650
# id,quodmaximeplaceat,facerepossimus,omnisvoluptasassumendaest,omnis
# 2651
# dolorrepellendus.Temporibusautemquibusdametautofficiisdebitisaut
# 2652
# rerumnecessitatibussaepeeveniet,utetvoluptatesrepudiandaesintet
# 2653
# molestiaenonrecusandae.Itaqueearumrerumhicteneturasapientedelectus,
# 2654
# utautreiciendisvoluptatibusmaioresaliasconsequaturautperferendis
# 2655
# doloribusasperioresrepellat.}
# 2656
# %{39}
# 2657
# \NewLipsumPar{Hancegocumteneamsententiam,quidestcurverear,neadeam
# 2658
# nonpossimaccommodareTorquatosnostros?Quostupauloantecummemoriter,
# 2659
# tumetiamerganosamiceetbenivolecollegisti,necmetamenlaudandis
# 2660
# maioribusmeiscorrupistinecsegnioremadrespondendumreddidisti.Quorum
# 2661
# factaquemadmodum,quaeso,interpretaris?Sicineeoscensesautinarmatum
# 2662
# hostemimpetumfecisseautinliberosatqueinsanguinemsuumtamcrudelis
# 58
#
# 2663
# fuisse,nihilutdeutilitatibus,nihilutdecommodissuiscogitarent?Atid
# 2664
# neferaequidemfaciunt,utitaruantitaqueturbent,utearummotuset
# 2665
# impetusquopertineantnonintellegamus,tutamegregiosviroscensestantas
# 2666
# resgessissesinecausa?}
# 2667
# %{40}
# 2668
# \NewLipsumPar{Quaefueritcausa,moxvidero;intereahoctenebo,siobaliquam
# 2669
# causamista,quaesinedubiopraeclarasunt,fecerint,virtutemiisperse
# 2670
# ipsamcausamnonfuisse.\textendash\spaceTorquemdetraxithosti.
# 2671
# \textendash\spaceEtquidemsetexit,neinteriret.\textendash\spaceAt
# 2672
# magnumpericulumadiit.\textendash\spaceInoculisquidemexercitus.
# 2673
# \textendash\spaceQuidexeoestconsecutus?\textendash\spaceLaudemet
# 2674
# caritatem,quaesuntvitaesinemetudegendaepraesidiafirmissima.
# 2675
# \textendash\spaceFiliummortemultavit.\textendash\spaceSisinecausa,
# 2676
# nollemmeabeoortum,taminportunotamquecrudeli;sin,utdoloresuo
# 2677
# sanciretmilitarisimperiidisciplinamexercitumqueingravissimobello
# 2678
# animadversionismetucontineret,salutiprospexitcivium,quaintellegebat
# 2679
# continerisuam.Atquehaecratiolatepatet.}
# 2680
# %{41}
# 2681
# \NewLipsumPar{Inquoenimmaximeconsuevitiactarevestraseoratio,tua
# 2682
# praesertim,quistudioseantiquapersequeris,clarisetfortibusviris
# 2683
# commemorandiseorumquefactisnonemolumentoaliquo,sedipsiushonestatis
# 2684
# decorelaudandis,idtotumevertitureodelecturerum,quemmododixi,
# 2685
# constituto,utautvoluptatesomittanturmaiorumvoluptatumadipiscendarum
# 2686
# causaautdoloressuscipianturmaiorumdolorumeffugiendorumgratia.}
# 2687
# %{42}
# 2688
# \NewLipsumPar{Seddeclarorumhominumfactisillustribusetgloriosissatis
# 2689
# hoclocodictumsit.Eritenimiamdeomniumvirtutumcursuadvoluptatem
# 2690
# propriusdisserendilocus.Nuncautemexplicabo,voluptasipsaquaequalisque
# 2691
# sit,uttollaturerroromnisimperitorumintellegaturqueea,quaevoluptaria,
# 2692
# delicata,mollishabeaturdisciplina,quamgravis,quamcontinens,quamsevera
# 2693
# sit.Nonenimhancsolamsequimur,quaesuavitatealiquanaturamipsammovet
# 2694
# etcumiucunditatequadampercipitursensibus,sedmaximamvoluptatemillam
# 2695
# habemus,quaepercipituromnidoloredetracto,namquoniam,cumprivamur
# 2696
# dolore,ipsaliberationeetvacuitateomnismolestiaegaudemus,omneautemid,
# 2697
# quogaudemus,voluptasest,utomne,quooffendimur,dolor,dolorisomnis
# 2698
# privatiorectenominataestvoluptas.Utenim,cumciboetpotionefames
# 2699
# sitisquedepulsaest,ipsadetractiomolestiaeconsecutionemaffert
# 2700
# voluptatis,sicinomniredolorisamotiosuccessionemefficitvoluptatis.}
# 2701
# %{43}
# 2702
# \NewLipsumPar{ItaquenonplacuitEpicuromediumessequiddaminterdoloremet
# 2703
# voluptatem;illudenimipsum,quodquibusdammediumvideretur,cumomnidolore
# 2704
# careret,nonmodovoluptatemesse,verumetiamsummamvoluptatem.Quisquis
# 2705
# enimsentit,quemadmodumsitaffectus,eumnecesseestautinvoluptateesse
# 2706
# autindolore.OmnisautemprivationedolorisputatEpicurusterminarisummam
# 2707
# voluptatem,utposteavariarivoluptasdistinguiquepossit,augeri
# 2708
# amplificariquenonpossit.}
# 2709
# %{44}
# 2710
# \NewLipsumPar{AtetiamAthenis,utepatreaudiebamfaceteeturbaneStoicos
# 2711
# irridente,statuaestinCeramicoChrysippisedentisporrectamanu,quaemanus
# 2712
# significetilluminhaeesserogatiunculadelectatum:\textquoteleft
# 2713
# Numquidnammanustuasicaffecta,quemadmodumaffectanuncest,
# 2714
# desiderat?\textquoteright\space\textendash\spaceNihilsane.
# 2715
# \textendash\space\textquoteleftAt,sivoluptasessetbonum,
# 2716
# desideraret.\textquoteright\space\textendash\spaceItacredo.
# 2717
# \textendash\space\textquoteleftNonestigiturvoluptas
# 2718
# bonum.\textquoteright\spaceHocnestatuamquidemdicturampateraiebat,si
# 2719
# loquiposset.ConclusumestenimcontraCyrenaicossatisacute,nihilad
# 2720
# Epicurum.Namsieasolavoluptasesset,quaequasititillaretsensus,utita
# 2721
# dicam,etadeoscumsuavitateafflueretetillaberetur,necmanusesse
# 2722
# contentapossetnecullaparsvacuitatedolorissineiucundomotuvoluptatis.
# 2723
# Sinautemsummavoluptasest,utEpicuroplacet,nihildolere,primumtibi
# 2724
# recte,Chrysippe,concessumestnihildesideraremanum,cumitaessetaffecta,
# 2725
# secundumnonrecte,sivoluptasessetbonum,fuissedesideraturam.Idcirco
# 59
#
# 2726
# enimnondesideraret,quia,quoddolorecaret,idinvoluptateest.}
# 2727
# %{45}
# 2728
# \NewLipsumPar{Extremumautemessebonorumvoluptatemexhocfacillimeperspici
# 2729
# potest:Constituamusaliquemmagnis,multis,perpetuisfruentemetanimoet
# 2730
# corporevoluptatibusnullodolorenecimpedientenecinpendente,quemtandem
# 2731
# hocstatupraestabilioremautmagisexpetendumpossimusdicere?Inesseenim
# 2732
# necesseestineo,quiitasitaffectus,etfirmitatemaniminecmortemnec
# 2733
# doloremtimentis,quodmorssensucareat,dolorinlonginquitatelevis,in
# 2734
# gravitatebrevissoleatesse,uteiusmagnitudinemceleritas,diuturnitatem
# 2735
# allevatioconsoletur.}
# 2736
# %{46}
# 2737
# \NewLipsumPar{Adeacumaccedit,utnequedivinumnumenhorreatnec
# 2738
# praeteritasvoluptateseffluerepatiaturearumqueassiduarecordatione
# 2739
# laetetur,quidest,quodhucpossit,quodmeliussit,accedere?Statuecontra
# 2740
# aliquemconfectumtantisanimicorporisquedoloribus,quantiinhominemmaximi
# 2741
# caderepossunt,nullaspepropositaforeleviusaliquando,nullapraeterea
# 2742
# nequepraesentinecexpectatavoluptate,quideomiseriusdiciautfingi
# 2743
# potest?Quodsivitadoloribusrefertamaximefugiendaest,summumprofecto
# 2744
# malumestviverecumdolore,cuisententiaeconsentaneumestultimumesse
# 2745
# bonorumeumvoluptatevivere.Necenimhabetnostramensquicquam,ubi
# 2746
# consistattamquaminextremo,omnesqueetmetusetaegritudinesaddolorem
# 2747
# referuntur,necpraetereaestresulla,quaesuanaturaautsollicitarepossit
# 2748
# autangere.}
# 2749
# %{47}
# 2750
# \NewLipsumPar{Praetereaetappetendietrefugiendietomninorerumgerendarum
# 2751
# initiaproficiscunturautavoluptateautadolore.Quodcumitasit,
# 2752
# perspicuumestomnisrectasresatquelaudabiliseoreferri,utcumvoluptate
# 2753
# vivatur.Quoniamautemidestvelsummumbonorumvelultimumvelextremum
# 2754
# \textendash\spacequodGraeci[\ldots]nominant\textendash,quodipsumnullam
# 2755
# adaliamrem,adidautemresreferunturomnes,fatendumestsummumessebonum
# 2756
# iucundevivere.}
# 2757
# %{48}
# 2758
# \NewLipsumPar{Idquiinunavirtuteponuntetsplendorenominiscaptiquid
# 2759
# naturapostuletnonintellegunt,erroremaximo,siEpicurumaudirevoluerint,
# 2760
# liberabuntur:istaeenimvestraeeximiaepulchraequevirtutesnisivoluptatem
# 2761
# efficerent,quiseasautlaudabilisautexpetendasarbitraretur?Utenim
# 2762
# medicorumscientiamnonipsiusartis,sedbonaevaletudiniscausaprobamus,et
# 2763
# gubernatorisars,quiabenenavigandirationemhabet,utilitate,nonarte
# 2764
# laudatur,sicsapientia,quaearsvivendiputandaest,nonexpeteretur,si
# 2765
# nihilefficeret;nuncexpetitur,quodesttamquamartifexconquirendaeet
# 2766
# comparandaevoluptatis\textendash}
# 2767
# %{49}
# 2768
# \NewLipsumPar{Quamautemegodicamvoluptatem,iamvidetis,neinvidiaverbi
# 2769
# labefacteturoratiomea\textendash.Namcumignorationererumbonarumet
# 2770
# malarummaximehominumvitavexetur,obeumqueerroremetvoluptatibusmaximis
# 2771
# saepepriventuretdurissimisanimidoloribustorqueantur,sapientiaest
# 2772
# adhibenda,quaeetterroribuscupiditatibusquedetractisetomniumfalsarum
# 2773
# opinionumtemeritatedereptacertissimamsenobisducempraebeatad
# 2774
# voluptatem.Sapientiaenimestuna,quaemaestitiampellatexanimis,quaenos
# 2775
# exhorresceremetunonsinat.Quapraeceptriceintranquillitatevivipotest
# 2776
# omniumcupiditatumardorerestincto.Cupiditatesenimsuntinsatiabiles,quae
# 2777
# nonmodosinguloshomines,seduniversasfamiliasevertunt,totametiam
# 2778
# labefactantsaeperempublicam.}
# 2779
# %{50}
# 2780
# \NewLipsumPar{Excupiditatibusodia,discidia,discordiae,seditiones,bella
# 2781
# nascuntur,neceaeseforissolumiactantnectantuminalioscaecoimpetu
# 2782
# incurrunt,sedintusetiaminanimisinclusaeintersedissidentatque
# 2783
# discordant,exquovitamamarissimamnecesseesteffici,utsapienssolum
# 2784
# amputatacircumcisaqueinanitateomnieterrorenaturaefinibuscontentussine
# 2785
# aegritudinepossitetsinemetuvivere.}
# 2786
# %{51}
# 2787
# \NewLipsumPar{Quaeestenimaututiliorautadbenevivendumaptiorpartitio
# 2788
# quamilla,quaestususEpicurus?Quiunumgenusposuitearumcupiditatum,
# 60
#
# 2789
# quaeessentetnaturalesetnecessariae,alterum,quaenaturalesessentnec
# 2790
# tamennecessariae,tertium,quaenecnaturalesnecnecessariae.Quarumea
# 2791
# ratioest,utnecessariaenecoperamultanecimpensaexpleantur;nenaturales
# 2792
# quidemmultadesiderant,proptereaquodipsanaturadivitias,quibuscontenta
# 2793
# sit,etparabilisetterminatashabet;inaniumautemcupiditatumnecmodus
# 2794
# ullusnecfinisinveniripotest.}
# 2795
# %{52}
# 2796
# \NewLipsumPar{Quodsivitamomnemperturbarividemuserroreetinscientia,
# 2797
# sapientiamqueessesolam,quaenosalibidinumimpetuetaformidinumterrore
# 2798
# vindicetetipsiusfortunaemodiceferredoceatiniuriasetomnismonstret
# 2799
# vias,quaeadquietemetadtranquillitatemferant,quidestcurdubitemus
# 2800
# dicereetsapientiamproptervoluptatesexpetendametinsipientiampropter
# 2801
# molestiasessefugiendam?}
# 2802
# %{53}
# 2803
# \NewLipsumPar{Eademquerationenetemperantiamquidempropterseexpetendam
# 2804
# essedicemus,sedquiapacemanimisafferateteosquasiconcordiaquadam
# 2805
# ...
# 4188
# gravivulnereexanimarisevideret,utprimumdispexit,quaesivitsalvusne
# 4189
# essetclipeus.Cumsalvumesseflentessuirespondissent,rogavitessentne
# 4190
# fusihostes.Cumidquoque,utcupiebat,audivisset,evelliiussiteam,qua
# 4191
# erattransfixus,hastam.Itamultosanguineprofusoinlaetitiaetinvictoria
# 4192
# estmortuus.Leonidasautem,rexLacedaemoniorum,seinThermopylis
# 4193
# trecentosqueeos,quoseduxeratSparta,cumessetpropositaautfugaturpis
# 4194
# autgloriosamors,opposuithostibus.Praeclaraemortessuntimperatoriae;
# 4195
# philosophiauteminsuislectulisplerumquemoriuntur.Referttamen,quomodo.
# 4196
# (beatus)sibivideturessemoriens.Magnalaus.\textquoteleft
# 4197
# Compensabatur\textquoteright,inquit,\textquoteleftcumsummisdoloribus
# 4198
# laetitia.\textquoteright}
# 4199
# %{178}
# 4200
# \NewLipsumPar{Audioequidemphilosophivocem,Epicure,sedquidtibidicendum
# 4201
# sitoblituses.Primumenim,siverasuntea,quorumrecordationetegaudere
# 4202
# dicis,hocest,siverasunttuascriptaetinventa,gauderenonpotes.Nihil
# 4203
# enimiamhabes,quodadcorpusreferas;estautematesemperdictumnec
# 4204
# gauderequemquamnisiproptercorpusnecdolere.\textquoteleft
# 4205
# Praeteritis\textquoteright,inquit,\textquoteleft
# 4206
# gaudeo.\textquoteright\spaceQuibusnampraeteritis?Siadcorpus
# 4207
# pertinentibus,rationestuastevideocompensarecumistisdoloribus,non
# 4208
# memoriamcorporeperceptarumvoluptatum;sinautemadanimum,falsumest,quod
# 4209
# negasanimiullumessegaudium,quodnonreferaturadcorpus.Curdeinde
# 4210
# Metrodoriliberoscommendas?Quid(in)istoegregiotuoofficioettanta
# 4211
# fide\textendashsicenimexistimo\textendashadcorpusrefers?}
# 4212
# %{179}
# 4213
# \NewLipsumPar{Hucetilluc,Torquate,vosversetislicet,nihilinhac
# 4214
# praeclaraepistulascriptumabEpicurocongruensetconveniensdecretiseius
# 4215
# reperietis.Itaredarguituripseasese,convincunturquescriptaeius
# 4216
# probitateipsiusacmoribus.Namistacommendatiopuerorum,memoriaetcaritas
# 4217
# amicitiae,summorumofficioruminextremospirituconservatioindicatinnatam
# 4218
# essehominiprobitatemgratuitam,noninvitatamvoluptatibusnecpraemiorum
# 4219
# mercedibusevocatam.Quodenimtestimoniummaiusquaerimus,quaehonestaet
# 4220
# rectasint,ipsaesseoptabiliapersese,cumvideamustantaofficia
# 4221
# morientis?}
# 4222
# %{180}
# 4223
# \NewLipsumPar{Sedutepistulamlaudandamarbitroream,quammodototidemfere
# 4224
# verbisinterpretatussum,quamquameacumsummaeiusphilosophianullomodo
# 4225
# congruebat,siceiusdemtestamentumnonsolum(a)philosophigravitate,sed
# 4226
# etiamabipsiussententiaiudicodiscrepare.Scripsitenimetmultissaepe
# 4227
# verbisetbreviterartequeineolibro,quemmodonominavi,mortemnihilad
# 4228
# nospertinere.Quodenimdissolutumsit,idessesinesensu,quodautemsine
# 4229
# sensusit,idnihiladnospertinereomnino.Hocipsumelegantiusponi
# 4230
# meliusquepotuit.Namquoditapositumest,quoddissolutumsit,idessesine
# 4231
# sensu,ideiusmodiest,utnonsatisplanedicatquidsitdissolutum.}
# 4232
# %{181}
# 4233
# \NewLipsumPar{Sedtamenintellegoquidvelit.Quaeroautemquidsit,quod,cum
# 4234
# dissolutione,idestmorte,sensusomnisextinguatur,etcumreliquinihilsit
# 4235
# omnino,quodpertineatadnos,tamaccuratetamquediligentercaveatet
# 4236
# sanciatutAmynomachusetTimocrates,heredessui,deHermarchisententiadent
# 4237
# quodsatissitaddiemagendumnatalemsuumquotannismenseGamelioneitemque
# 83
#
# 4238
# omnibusmensibusvicesimodielunaedentadeorumepulas,quiunasecum
# 4239
# philosophatisint,utetsuietMetrodorimemoriacolatur.}
# 4240
# %{182}
# 4241
# \NewLipsumPar{Haecegononpossumdicerenonessehominisquamvisetbelliet
# 4242
# humani,sapientisveronullomodo,physicipraesertim,quemseilleessevult,
# 4243
# putareullumessecuiusquamdiemnatalem.Quid?Idemnepotestessedies
# 4244
# saepius,quisemelfuit?Certenonpotest.Aneiusdemmodi?Neidquidem,nisi
# 4245
# multaannorumintercesserintmilia,utomniumsiderumeodem,undeprofecta
# 4246
# sint,fiatadunumtempusreversio.Nullusestigiturcuiusquamdiesnatalis.
# 4247
# \textquoteleftAthabetur!\textquoteright\spaceEtegoidscilicetnesciebam!
# 4248
# Sedutsit,etiamnepostmortemcoletur?Idquetestamentocavebitis,qui
# 4249
# nobisquasioraculumedideritnihilpostmortemadnospertinere?Haecnon
# 4250
# eranteius,quiinnumerabilismundosinfinitasqueregiones,quarumnullaesset
# 4251
# ora,nullaextremitas,menteperagravisset.NumquidtaleDemocritus?Utalios
# 4252
# omittam,huncappello,quemilleunumsecutusest.}
# 4253
# %{183}
# 4254
# \NewLipsumPar{Quodsidiesnotandusfuit,eumnepotius,quonatus,aneum,quo
# 4255
# sapiensfactusest?Nonpotuit,inquies,fierisapiens,nisinatusesset.[et]
# 4256
# Istomodo,nesiaviaquidemeiusnatanonesset.Restota,Torquate,non
# 4257
# doctorumhominum,vellepostmortemepuliscelebrarimemoriamsuinominis.
# 4258
# Quosquidemdiesquemadmodumagatisetinquantamhominumfacetorum
# 4259
# urbanitatemincurratis,nondico\textendash\spacenihilopusest
# 4260
# litibus\textendash;tantumdico,magisfuissevestrumagereEpicuridiem
# 4261
# natalem,quamilliustestamentocavereutageretur.}
# 4262
# %{184}
# 4263
# \NewLipsumPar{Sedutadpropositum\textendashdedoloreenimcumdiceremus,ad
# 4264
# istamepistulamdelatisumus\textendash,nunctotumilludconcludisiclicet:
# 4265
# quiinsummomaloest,istum,cumineoest,nonestbeatus;sapiensautem
# 4266
# semperbeatusestetestaliquandoindolore;nonestigitursummummalum
# 4267
# dolor.Iamilludqualetandemest,bonapraeteritanonefflueresapienti,mala
# 4268
# meminissenonoportere?Primuminnostranepotestateest,quidmeminerimus?
# 4269
# Themistoclesquidem,cumeiSimonidesanquisaliusartemmemoriae
# 4270
# polliceretur,\textquoteleftOblivionis\textquoteright,inquit,\textquoteleft
# 4271
# mallem.Nammeminietiamquaenolo,obliviscinonpossumquae
# 4272
# volo.\textquoteright}
# 4273
# %{185}
# 4274
# \NewLipsumPar{Magnohicingenio,sedressetamensichabet,utnimis
# 4275
# imperiosiphilosophisitvetarememinisse.VideneistasintManlianavestra
# 4276
# autmaioraetiam,siimperesquodfacerenonpossim.Quid,sietiamiucunda
# 4277
# memoriaestpraeteritorummalorum?Utproverbianonnullaveriorasintquam
# 4278
# vestradogmata.Vulgoenimdicitur:\textquoteleftIucundiacti
# 4279
# labores\textquoteright,necmaleEuripides\textendash\spaceconcludam,si
# 4280
# potero,Latine;Graecumenimhuncversumnostisomnes\textendash:
# 4281
# \textquoteleftSuavislaborumestpraeteritorummemoria.\textquoteright\space
# 4282
# Sedadbonapraeteritaredeamus.Quaesiavobistaliadicerentur,qualibus
# 4283
# CaiusMariusutipoterat,utexpulsus,egens,inpaludedemersustropaeorum
# 4284
# recordationelevaretdoloremsuum,audiremetplaneprobarem.Necenimabsolvi
# 4285
# beatavitasapientisnequeadexitumperducipoterit,siprimaquaequebeneab
# 4286
# eoconsultaatquefactaipsiusoblivioneobruentur.}
# 4287
# %{186}
# 4288
# \NewLipsumPar{Sedvobisvoluptatumperceptarumrecordatiovitambeatamfacit,
# 4289
# etquidemcorporeperceptarum.Namsiquaesuntaliae,falsumestomnisanimi
# 4290
# voluptatesesseecorporissocietate.Corporisautemvoluptassietiam
# 4291
# praeteritadelectat,nonintellego,curAristotelesSardanapalliepigramma
# 4292
# tantoperederideat,inquoillerexSyriaeglorieturseomnissecumlibidinum
# 4293
# voluptatesabstulisse.Quodenimnevivusquidem,inquit,diutiussentire
# 4294
# poterat,quamdumfruebatur,quomodoidpotuitmortuopermanere?Effluit
# 4295
# igiturvoluptascorporisetprimaquaequeavolatsaepiusquerelinquitcausam
# 4296
# paenitendiquamrecordandi.ItaquebeatiorAfricanuscumpatriaillomodo
# 4297
# loquens:\textquoteleftDesine,Roma,tuoshostes\textquoteright\space
# 4298
# reliquaquepraeclare:\textquoteleftNamtibimoenimentameipeperere
# 4299
# labores.\textquoteright\spaceLaboribushicpraeteritisgaudet,tuiubes
# 4300
# voluptatibus,ethicseadearevocat,equibusnihilumquamrettuleritad
# 84
#
# 4301
# corpus,tutotushaeresincorpore.}
# 4302
# %{187}
# 4303
# \NewLipsumPar{Illudautemipsumquioptineripotest,quoddicitis,omnisanimi
# 4304
# etvoluptatesetdoloresadcorporisvoluptatesacdolorespertinere?Nihilne
# 4305
# tedelectatumquam\textendashvideo,quicumloquar\textendash,teigitur,
# 4306
# Torquate,ipsumpersenihildelectat?Omittodignitatem,honestatem,speciem
# 4307
# ipsamvirtutum,dequibusantedictumest,haeclevioraponam:poema,
# 4308
# orationemcumautscribisautlegis,cumomniumfactorum,cumregionum
# 4309
# conquirishistoriam,signum,tabula,locusamoenus,ludi,venatio,villa
# 4310
# Luculli\textendashnamsi\textquotelefttuam\textquoteright\spacedicerem,
# 4311
# latebramhaberes;adcorpusdicerespertinere\textendash,sedea,quaedixi,
# 4312
# adcorpusnerefers?Anestaliquid,quodtesuaspontedelectet?Aut
# 4313
# pertinacissimusfueris,siineoperstiterisadcorpusea,quaedixi,referri,
# 4314
# autdeserueristotamEpicurivoluptatem,sinegaveris.}
# 4315
# %{188}
# 4316
# \NewLipsumPar{Quodveroatedisputatumestmaioresessevoluptatesetdolores
# 4317
# animiquamcorporis,quiatriumtemporumparticepsanimussit,corporeautem
# 4318
# praesentiasolumsentiantur,quiidprobaripotest,utis,quipropterme
# 4319
# aliquidgaudeat,plusquamegoipsegaudeat?[animovoluptasoriturpropter
# 4320
# voluptatemcorporis,etmaiorestanimivoluptasquamcorporis.Itafit,ut
# 4321
# gratulatorlaetiorsitquamis,cuigratulatur.]Seddumefficerevultis
# 4322
# beatumsapientem,cummaximasanimovoluptatespercipiatomnibusquepartibus
# 4323
# maioresquamcorpore,quidoccurratnonvidetis.Animienimquoquedolores
# 4324
# percipietomnibuspartibusmaioresquamcorporis.Itamisersitaliquando
# 4325
# necesseestis,quemvosbeatumsempervultisesse,necveroid,dumomniaad
# 4326
# voluptatemdoloremquereferetis,efficietisumquam.}
# 4327
# %{189}
# 4328
# \NewLipsumPar{Quarealiudaliquod,Torquate,hominissummumbonumreperiendum
# 4329
# est,voluptatembestiisconcedamus,quibusvosdesummobonotestibusuti
# 4330
# soletis.Quid,sietiambestiaemultafaciuntducesuaquaequenaturapartim
# 4331
# indulgentervelcumlabore,utingignendo,ineducando,perfacileappareat
# 4332
# aliudquiddamiispropositum,nonvoluptatem?Partimcursuetperagratione
# 4333
# laetantur,congregationealiaecoetumquodammodocivitatisimitantur;}
# 4334
# %{190}
# 4335
# \NewLipsumPar{Videmusinquodamvolucriumgenerenonnullaindiciapietatis,
# 4336
# cognitionem,memoriam,inmultisetiamdesideriavidemus.Ergoinbestiis
# 4337
# eruntsecretaevoluptatehumanarumquaedamsimulacravirtutum,inipsis
# 4338
# hominibusvirtusnisivoluptatiscausanullaerit?Ethomini,quiceteris
# 4339
# animantibusplurimumpraestat,praecipueanaturanihildatumessedicemus?}
# 4340
# %{191}
# 4341
# \NewLipsumPar{Nosvero,siquideminvoluptatesuntomnia,longemultumque
# 4342
# superamurabestiis,quibusipsaterrafunditexsesepastusvariosatque
# 4343
# abundantesnihillaborantibus,nobisautemautvixautnevixquidemsuppetunt
# 4344
# multolaborequaerentibus.Nectamenullomodosummumpecudisbonumethominis
# 4345
# idemmihivideripotest.Quidenimtantoopusestinstrumentoinoptimis
# 4346
# artibuscomparandis?Quidtantoconcursuhonestissimorumstudiorum,tanto
# 4347
# virtutumcomitatu,sieanullamadaliamremnisiadvoluptatemconquiruntur?}
# 4348
# %{192}
# 4349
# \NewLipsumPar{Ut,siXerxes,cumtantisclassibustantisqueequestribuset
# 4350
# pedestribuscopiisHellespontoiunctoAthoneperfossomariambulavissetterra
# 4351
# navigavisset,si,cumtantoimpetuinGraeciamvenisset,causamquisexeo
# 4352
# quaererettantarumcopiarumtantiquebelli,melseauferreexHymettovoluisse
# 4353
# diceret,certesinecausavidereturtantaconatus,sicnossapientemplurimis
# 4354
# etgravissimisartibusatquevirtutibusinstructumetornatumnon,utillum,
# 4355
# mariapedibusperagrantem,classibusmontes,sedomnecaelumtotamquecum
# 4356
# universomariterrammentecomplexumvoluptatempeteresidicemus,mellis
# 4357
# causadicemustantamolitum.}
# 4358
# %{193}
# 4359
# \NewLipsumPar{Adaltioraquaedametmagnificentiora,mihicrede,Torquate,
# 4360
# natisumus,necidexanimisolumpartibus,inquibusinestmemoriarerum
# 4361
# innumerabilium,intequideminfinita,inestconiecturaconsequentiumnon
# 4362
# multumadivinationedifferens,inestmoderatorcupiditatispudor,inestad
# 4363
# humanamsocietatemiustitiaefidacustodia,inestinperpetiendislaboribus
# 85
#
# 4364
# adeundisquepericulisfirmaetstabilisdolorismortisque
# 4365
# contemptio\textendashergohaecinanimis,tuautemetiammembraipsa
# 4366
# sensusqueconsidera,quitibi,utreliquaecorporispartes,noncomitessolum
# 4367
# virtutum,sedministrietiamvidebuntur.}
# 4368
# %{194}
# 4369
# \NewLipsumPar{Quid?Siinipsocorporemultavoluptatipraeponendasunt,ut
# 4370
# vires,valitudo,velocitas,pulchritudo,quidtandeminanimiscenses?In
# 4371
# quibusdoctissimiilliveteresinessequiddamcaelesteetdivinumputaverunt.
# 4372
# Quodsiessetinvoluptatesummumbonum,utdicitis,optabileessetmaximain
# 4373
# voluptatenullointervallointeriectodiesnoctesqueversari,cumomnessensus
# 4374
# dulcedineomniquasiperfusimoverentur.Quisestautemdignusnominehominis,
# 4375
# quiunumdiemtotumvelitesseingenereistovoluptatis?Cyrenaiciquidemnon
# 4376
# recusant;vestrihaecverecundius,illifortasseconstantius.}
# 4377
# %{195}
# 4378
# \NewLipsumPar{Sedlustremusanimononhasmaximasartis,quibusquicarebant
# 4379
# inertesamaioribusnominabantur,sedquaeronumexistimes,nondicoHomerum,
# 4380
# Archilochum,Pindarum,sedPhidian,Polyclitum,Zeuximadvoluptatemartes
# 4381
# suasdirexisse.Ergoopifexplussibiproponetadformarumquamcivis
# 4382
# excellensadfactorumpulchritudinem?Quaeautemestaliacausaerroristanti
# 4383
# tamlongelatequediffusi,nisiquodis,quivoluptatemsummumbonumesse
# 4384
# decernit,noncumeaparteanimi,quainestratioatqueconsilium,sedcum
# 4385
# cupiditate,idestcumanimilevissimaparte,deliberat?Quaeroenimdete,si
# 4386
# suntdi,utvosetiamputatis,quipossintessebeati,cumvoluptatescorpore
# 4387
# perciperenonpossint,aut,sisineeogenerevoluptatisbeatisint,cur
# 4388
# similemanimiusuminsapienteessenolitis.}
# 4389
# %{196}
# 4390
# \NewLipsumPar{Legelaudationes,Torquate,noneorum,quisuntabHomero
# 4391
# laudati,nonCyri,nonAgesilai,nonAristidiautThemistocli,nonPhilippi
# 4392
# autAlexandri,legenostrorumhominum,legevestraefamiliae;neminemvidebis
# 4393
# italaudatum,utartifexcalliduscomparandarumvoluptatumdiceretur.Non
# 4394
# elogiamonimentorumidsignificant,veluthocadportam:\textquoteleftHunc
# 4395
# unumplurimaeconsentiuntgentespopuliprimariumfuisse
# 4396
# virum.\textquoteright}
# 4397
# %{197}
# 4398
# \NewLipsumPar{IdneconsensissedeCalatinoplurimasgentisarbitramur,
# 4399
# primariumpopulifuisse,quodpraestantissimusfuissetinconficiendis
# 4400
# voluptatibus?Ergoiniisadolescentibusbonamspemessedicemusetmagnam
# 4401
# indolem,quossuiscommodisinserviturosetquicquidipsisexpediatfacturos
# 4402
# arbitrabimur?Nonnevidemusquantaperturbatiorerumomniumconsequatur,
# 4403
# quantaconfusio?Tolliturbeneficium,tolliturgratia,quaesuntvincla
# 4404
# concordiae.Necenim,cumtuacausacuicommodes,beneficiumilludhabendum
# 4405
# est,sedfaeneratio,necgratiadeberivideturei,quisuacausacommodaverit.
# 4406
# Maximasverovirtutesiacereomnisnecesseestvoluptatedominante.Suntetiam
# 4407
# turpitudinesplurimae,quae,nisihonestasnaturaplurimumvaleat,curnon
# 4408
# cadantinsapientemnonestfaciledefendere.}
# 4409
# %{198}
# 4410
# \NewLipsumPar{Acnepluracomplectar\textendashsuntenim
# 4411
# innumerabilia\textendash,benelaudatavirtusvoluptatisaditusintercludat
# 4412
# necesseest.Quodiamameexpectarenoli.Tuteintrospiceinmentemtuamipse
# 4413
# eamqueomnicogitationepertractanspercontareipseteperpetuisnemalis
# 4414
# voluptatibusperfruensinea,quamsaepeusurpabas,tranquillitatedegere
# 4415
# omnemaetatemsinedolore,adsumptoetiamillo,quodvosquidemadiungere
# 4416
# soletis,sedfierinonpotest,sinedolorismetu,an,cumdeomnibusgentibus
# 4417
# optimemererere,cumopemindigentibussalutemqueferres,velHerculisperpeti
# 4418
# aerumnas.Sicenimmaioresnostrilaboresnonfugiendostristissimotamen
# 4419
# verboaerumnasetiamindeonominaverunt.}
# 4420
# %{199}
# 4421
# \NewLipsumPar{Eliceremextecogeremque,utresponderes,nisiverererne
# 4422
# Herculemipsumea,quaeprosalutegentiumsummolaboregessisset,voluptatis
# 4423
# causagessissediceres.Quaecumdixissem,Habeo,inquitTorquatus,adquos
# 4424
# istareferam,et,quamquamaliquidipsepoteram,tameninveniremalo
# 4425
# paratiores.Familiaresnostros,credo,SironemdicisetPhilodemum,cum
# 4426
# optimosviros,tumhominesdoctissimos.Recte,inquit,intellegis.Agesane,
# 86
#
# 4427
# inquam.SederataequiusTriariumaliquiddedissensionenostraiudicare.
# 4428
# Eiuro,inquitadridens,iniquum,hacquidemdere;tuenimistalenius,hic
# 4429
# Stoicorummorenosvexat.TumTriarius:Posthacquidem,inquit,audacius.Nam
# 4430
# haecipsamihieruntinpromptu,quaemodoaudivi,necanteaggrediar,quamte
# 4431
# abistis,quosdicis,instructumvidero.Quaecumessentdicta,finemfecimus
# 4432
# etambulandietdisputandi.}
# 4433
# %{200}
# 4434
# \NewLipsumPar{Voluptatemquidem,Brute,siipsaproseloquaturnectam
# 4435
# pertinaceshabeatpatronos,concessuramarbitrorconvictamsuperiorelibro
# 4436
# dignitati.Etenimsitinpudens,sivirtutidiutiusrepugnet,autsihonestis
# 4437
# iucundaanteponatautplurisessecontendatdulcedinemcorporisexeavenatam
# 4438
# laetitiamquamgravitatemanimiatqueconstantiam.Quareillamquidem
# 4439
# dimittamusetsuissefinibustenereiubeamus,neblanditiiseius
# 4440
# inlecebrisqueimpediaturdisputandiseveritas.}
# 4441
# h
# =
# cicero
# i
# 87
